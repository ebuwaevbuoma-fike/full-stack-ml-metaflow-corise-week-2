# %% [markdown]
# # Week 2 Project

# %% [markdown]
# Once again, we’ll be using the [Women's Ecommerce Clothing Reviews Dataset from Kaggle](https://www.kaggle.com/datasets/nicapotato/womens-ecommerce-clothing-reviews), which Kaggle states is a
#
# > dataset revolving around the reviews written by customers. Its nine supportive features offer a great environment to parse out the text through its multiple dimensions. Because this is real commercial data, it has been anonymized, and references to the company in the review text and body have been replaced with “retailer”.
#
# The machine learning task will be sentiment analysis, classifying each review as having positive or negative sentiment.

# %% [markdown]
# ## Task 1: Training and Evaluating Sentiment Analysis Models Using Metaflow
#
# In this task, you'll use Metaflow to build two machine learning models for sentiment analysis: a baseline *"majority class"* classifier and your own custom model. You'll then train both models in parallel and experiment with different hyperparameters to optimize their performance. Finally, you'll use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Here's what you'll need to do:
#
# ### Step 1: Build the Workflows
# The first step in this task is to build the workflow(s) for sentiment analysis using the Metaflow framework. Start by creating a new flow in Metaflow and implementing the baseline *"majority class"* classifier. Then, build your own custom classifier using techniques you learned in Week 1, or any [helpful resources](https://outerbounds.com/docs/nlp-tutorial-L2/) you'd like. For your custom model, be sure to include steps for data preprocessing, model training, and evaluation.
#
# ### Step 2: Train Both Models in Parallel
# Once you've built your models, the next step is to train both models in parallel using the Metaflow framework. Use Metaflow to run both training jobs in parallel steps. If you get stuck, you may want to review the [FlowSpec branching documentation](https://docs.metaflow.org/metaflow/basics#branch).
#
# ### Step 3: Experiment with Hyperparameters
# After you've trained both models in parallel, the next step is to experiment with different hyperparameters to optimize their performance. Try different values for hyperparameters such as learning rate, batch size, and number of epochs, and record the results for each combination of hyperparameters as Data Artifacts in Metaflow.
#
# ### Step 4: Analyze the Results
# Finally, use this notebook and the Metaflow Client API to analyze the results of your different models and hyperparameters. Create visualizations to compare the performance of the two models and identify the best hyperparameters for each one.
#
# By completing this task, you'll gain experience working with the Metaflow framework and learn how to build and optimize machine learning workflows for sentiment analysis.

# %%
from collections import Counter
import pandas as pd
import numpy as np 
from termcolor import colored
import matplotlib.pyplot as plt
import seaborn as sns
import string

# You can style your plots here, but it is not part of the project.
YELLOW = '#FFBC00'
GREEN = '#37795D'
PURPLE = '#5460C0'
BACKGROUND = '#F4EBE6'
colors = [GREEN, PURPLE]
custom_params = {
    'axes.spines.right': False, 'axes.spines.top': False,
    'axes.facecolor':BACKGROUND, 'figure.facecolor': BACKGROUND, 
    'figure.figsize':(8, 8)
}
sns_palette = sns.color_palette(colors, len(colors))
sns.set_theme(style='ticks', rc=custom_params)

# %%
#import relevant packages
import pandas as pd
import io 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.dummy import DummyClassifier

# %%
#create a labeling fuction, ratings >=4 are positive

def labeling_function(row):
    """
    A function to derive labels from the user's review data.
    This could use many variables, or just one. 
    In supervised learning scenarios, this is a very important part of determining what the machine learns!
   
    A subset of variables in the e-commerce fashion review dataset to consider for labels you could use in ML tasks include:
        # rating: Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best.
        # recommended_ind: Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.
        # positive_feedback_count: Positive Integer documenting the number of other customers who found this review positive.

    In this case, we are doing sentiment analysis. 
    To keep things simple, we use the rating only, and return a binary positive or negative sentiment score based on an arbitrarty cutoff. 
    """
    # TODO: Add your logic for the labelling function here
    try:
        if int(row['rating']) >= 4:
            return 1
        else:
            return 0
    except:
        return np.nan

# %%
# TODO: load the data. 
df = pd.read_csv('../data/Womens Clothing E-Commerce Reviews.csv', index_col=0)

# transformations
df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
df = df[~df.review_text.isna()]
df['review'] = df['review_text'].astype('str')
_has_review_df = df[df['review_text'] != 'nan']
reviews = _has_review_df['review_text']
labels = _has_review_df.apply(labeling_function, axis=1)
df = pd.DataFrame({'label': labels, **_has_review_df})

# split into training and validation.
_df = pd.DataFrame({'review': reviews, 'label': labels})
traindf, valdf = train_test_split(_df, test_size=0.2)

# %%
#inspect categories of label: 1,0 as expected
valdf['label'].unique()
# Out:
# array([1, 0])

# %%
#Majority category is label 1 (ratings >=4)
valdf['label'].value_counts()
# Out:
# 1    3498
# 0    1031
# Name: label, dtype: int64

# %%
valdf.head(n=5)
# Out:
#                                                   review  label
# 15341  When this poncho first came online i ordered i...      1
# 776    I am long waisted and 5' 120 lbs. 34c. that be...      1
# 19352  This dress is great! the fit is perfect and ve...      1
# 18451  Love these jeans!!! they are the perfect fit f...      1
# 14650  Love this top.. very flattering and form figur...      1

# %%
# TODO: build the majority class baseline model.
#majority class = most frequently occurring category of valdf['label]
maj_clf = DummyClassifier(strategy="most_frequent")
maj_clf.fit(traindf["review"], traindf["label"])

# TODO: find the majority class in the labels. 🤔
#Majority category is label 1 (ratings >=4)
maj_cat_pred = maj_clf.predict(valdf["review"])

# TODO: score the model on valdf with a 2D metric space: sklearn.metrics.accuracy_score, sklearn.metrics.roc_auc_score
    # Documentation on suggested model-scoring approach: https://scikit-learn.org/stable/modules/model_evaluation.html

maj_acc = accuracy_score(valdf["label"], maj_cat_pred)
maj_roc = roc_auc_score(valdf["label"], maj_cat_pred)
print(f"majority category accuracy: {maj_acc}")
print(f"majority category roc: {maj_roc}")
# Out:
# majority category accuracy: 0.772355928461029
# majority category roc: 0.5

# %%
# Template for this cell
# %%writefile model.py
# # TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# # TODO: train the model on traindf.
# # TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# # TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

# import tensorflow as tf
# from tensorflow.keras import layers, optimizers, regularizers
# from sklearn.base import BaseEstimator, ClassifierMixin
# from sklearn.metrics import accuracy_score, roc_auc_score
# from sklearn.feature_extraction.text import CountVectorizer

# class NbowModel():
#     def __init__(self, vocab_sz):

#         self.vocab_sz = vocab_sz

#         # Instantiate the CountVectorizer
#         self.cv = CountVectorizer(
#             min_df=.005, max_df = .75, stop_words='english', 
#             strip_accents='ascii', max_features=self.vocab_sz
#         )

#         # Define the keras model
#         inputs = tf.keras.Input(shape=(self.vocab_sz,), 
#                                 name='input')
#         x = layers.Dropout(0.10)(inputs)
#         x = layers.Dense(
#             15, activation="relu",
#             kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
#         )(x)
#         predictions = layers.Dense(1, activation="sigmoid",)(x)
#         self.model = tf.keras.Model(inputs, predictions)
#         opt = optimizers.Adam(learning_rate=0.002)
#         self.model.compile(loss="binary_crossentropy", 
#                            optimizer=opt, metrics=["accuracy"])

#     def fit(self, X, y):
#         print(X.shape)
#         print(X[0])
#         res = self.cv.fit_transform(X).toarray()
#         self.model.fit(x=res, y=y, batch_size=32, 
#                        epochs=10, validation_split=.2)
    
#     def predict(self, X):
#         print(X.shape)
#         print(X[0])
#         res = self.cv.transform(X).toarray()
#         return self.model.predict(res)
    
#     def eval_acc(self, X, labels, threshold=.5):
#         return accuracy_score(labels, 
#                               self.predict(X) > threshold)
    
#     def eval_rocauc(self, X, labels):
#         return roc_auc_score(labels,  self.predict(X))

#     @property
#     def model_dict(self): 
#         return {'vectorizer':self.cv, 'model': self.model}

#     @classmethod
#     def from_dict(cls, model_dict):
#         "Get Model from dictionary"
#         nbow_model = cls(len(
#             model_dict['vectorizer'].vocabulary_
#         ))
#         nbow_model.model = model_dict['model']
#         nbow_model.cv = model_dict['vectorizer']
#         return nbow_model

# %%
# %%writefile model_1.py
# TODO: modify this custom model to your liking. Check out this tutorial for more on this class: https://outerbounds.com/docs/nlp-tutorial-L2/
# TODO: train the model on traindf.
# TODO: score the model on valdf with _the same_ 2D metric space you used in previous cell.
# TODO: test your model works by importing the model module in notebook cells, and trying to fit traindf and score predictions on the valdf data!

import tensorflow as tf
from tensorflow.keras import layers, optimizers, regularizers
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.feature_extraction.text import CountVectorizer

class NbowModel():
    def __init__(self, vocab_sz, epochs, batch_size):
        self.vocab_sz = vocab_sz
        self.epochs = epochs
        self.batch_size = batch_size

        # Instantiate the CountVectorizer
        self.cv = CountVectorizer(
            min_df=.005, max_df = .75, stop_words='english', 
            strip_accents='ascii', max_features=self.vocab_sz
        )

        # Define the keras model
        inputs = tf.keras.Input(shape=(self.vocab_sz,), 
                                name='input')
        x = layers.Dropout(0.10)(inputs)
        x = layers.Dense(
            15, activation="relu",
            kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
        )(x)
        predictions = layers.Dense(1, activation="sigmoid",)(x)
        self.model = tf.keras.Model(inputs, predictions)
        opt = optimizers.Adam(learning_rate=0.002)
        self.model.compile(loss="binary_crossentropy", 
                           optimizer=opt, metrics=["accuracy"])
        print(f"vocab_sz: {self.vocab_sz}")
        print(f"epochs: {self.epochs}")
        print(f"batch_size: {self.batch_size}")

    def fit(self, X, y):
        print(X.shape)
        print(X[0])
        res = self.cv.fit_transform(X).toarray()
        self.model.fit(x=res, y=y, batch_size=self.batch_size, 
                       epochs=self.epochs, validation_split=.2)
    
    def predict(self, X):
        print(X.shape)
        print(X[0])
        res = self.cv.transform(X).toarray()
        return self.model.predict(res)
    
    def eval_acc(self, X, labels, threshold=.5):
        return accuracy_score(labels, 
                              self.predict(X) > threshold)
    
    def eval_rocauc(self, X, labels):
        return roc_auc_score(labels,  self.predict(X))

    @property
    def model_dict(self): 
        return {'vectorizer':self.cv, 'model': self.model, "epochs": self.epochs, "batch_size": self.batch_size}

    @classmethod
    def from_dict(cls, model_dict):
        "Retrieve custom model from model dictionary"
        print(model_dict)
        nbow_model = cls(len(
            model_dict['vectorizer'].vocabulary_
        ), model_dict["epochs"], model_dict["batch_size"])
        nbow_model.epochs = model_dict["epochs"]
        nbow_model.cv = model_dict['vectorizer']
        return nbow_model
# Out:
# Writing model_1.py

# %%
#Train the custom model, as model_1
from model import NbowModel
model_1 = NbowModel(500, 20, 32)
model_1.fit(traindf["review"], traindf["label"])
# Out:
# vocab_sz: 500
# epochs: 20
# batch_size: 32
# (18112,)
# Absolutely wonderful - silky and sexy and comfortable
# Epoch 1/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.4838 - accuracy: 0.7770 - val_loss: 0.3249 - val_accuracy: 0.8639
# Epoch 2/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.3474 - accuracy: 0.8531 - val_loss: 0.3192 - val_accuracy: 0.8648
# Epoch 3/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3190 - accuracy: 0.8663 - val_loss: 0.3181 - val_accuracy: 0.8620
# Epoch 4/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3091 - accuracy: 0.8726 - val_loss: 0.3158 - val_accuracy: 0.8609
# Epoch 5/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.3020 - accuracy: 0.8780 - val_loss: 0.3204 - val_accuracy: 0.8631
# Epoch 6/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2983 - accuracy: 0.8812 - val_loss: 0.3276 - val_accuracy: 0.8576
# Epoch 7/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2868 - accuracy: 0.8880 - val_loss: 0.3309 - val_accuracy: 0.8628
# Epoch 8/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2797 - accuracy: 0.8855 - val_loss: 0.3344 - val_accuracy: 0.8623
# Epoch 9/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2715 - accuracy: 0.8944 - val_loss: 0.3367 - val_accuracy: 0.8567
# Epoch 10/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.9005 - val_loss: 0.3434 - val_accuracy: 0.8612
# Epoch 11/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2498 - accuracy: 0.9075 - val_loss: 0.3511 - val_accuracy: 0.8584
# Epoch 12/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2535 - accuracy: 0.9043 - val_loss: 0.3589 - val_accuracy: 0.8598
# Epoch 13/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2447 - accuracy: 0.9081 - val_loss: 0.3635 - val_accuracy: 0.8570
# Epoch 14/20
# 453/453 [==============================] - 1s 1ms/step - loss: 0.2381 - accuracy: 0.9133 - val_loss: 0.3712 - val_accuracy: 0.8556
# Epoch 15/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2311 - accuracy: 0.9196 - val_loss: 0.3764 - val_accuracy: 0.8556
# Epoch 16/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2221 - accuracy: 0.9251 - val_loss: 0.3957 - val_accuracy: 0.8496
# Epoch 17/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2282 - accuracy: 0.9231 - val_loss: 0.3949 - val_accuracy: 0.8476
# Epoch 18/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2218 - accuracy: 0.9273 - val_loss: 0.4036 - val_accuracy: 0.8518
# Epoch 19/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2147 - accuracy: 0.9295 - val_loss: 0.4053 - val_accuracy: 0.8471
# Epoch 20/20
# 453/453 [==============================] - 0s 1ms/step - loss: 0.2150 - accuracy: 0.9307 - val_loss: 0.4152 - val_accuracy: 0.8449

# %%
# %%writefile baseline_challenge.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass

# labeling_function = ... 
# TODO: Define your labeling function here.
#create a labeling fuction, ratings >=4 are positive

def labeling_function(row):
    """
    A function to derive labels from the user's review data.
    """
    # TODO: Add your logic for the labelling function here
    try:
        if int(row['rating']) >= 4:
            return 1
        else:
            return 0
    except:
        return np.nan

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        # df = ... 
        # TODO: load the data. 
        df = pd.read_csv(io.StringIO(self.data), index_col=0)

        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files


        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline model"

        #import relevant packages
        from sklearn.metrics import accuracy_score, roc_auc_score
        from sklearn.dummy import DummyClassifier
        
        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        maj_clf = DummyClassifier(strategy="most_frequent")
        maj_clf.fit(self.traindf["review"], self.traindf["label"])
    
        predictions = maj_clf.predict(self.valdf["review"]) # TODO: predict the majority class
        acc = accuracy_score(self.valdf["label"], predictions) # TODO: return the accuracy_score of these predictions
         
        rocauc = roc_auc_score(self.valdf["label"], predictions) # TODO: return the roc_auc_score of these predictions
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model_1 import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100, "epochs": 20, "batch_size": 32}, {'vocab_sz': 300, "epochs": 20, "batch_size": 32}, {'vocab_sz': 500, "epochs": 20, "batch_size": 32}]  
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(params["vocab_sz"], params["epochs"], params["batch_size"]) # TODO: instantiate your custom model here!
            model.fit(X=self.df['review'], y=self.df['label'])

            acc = model.eval_acc(self.valdf["review"].values, self.valdf["label"])# TODO: evaluate your custom model in an equivalent way to accuracy_score.

            rocauc = model.eval_rocauc(self.valdf["review"].values, self.valdf["label"])  # TODO: evaluate your custom model in an equivalent way to roc_auc_score.

            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))

        self.next(self.aggregate)

    @step
    def aggregate(self, inputs):
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge()
# Out:
# Writing baseline_challenge.py

# %%
#inspect baseline_challenge.py run
! python baseline_challenge.py run --data "../data/Womens Clothing E-Commerce Reviews.csv"
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file ../data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-07 22:19:49.524 Workflow starting (run-id 44), see it in the UI at https://ui-pw-2141923211.outerbounds.dev/BaselineChallenge/44
# 2023-05-07 22:19:49.700 [44/start/200 (pid 2340)] Task is starting.
# 2023-05-07 22:19:52.641 [44/start/200 (pid 2340)] num of rows in train set: 18112
# 2023-05-07 22:19:55.621 [44/start/200 (pid 2340)] num of rows in validation set: 4529
# 2023-05-07 22:19:55.819 [44/start/200 (pid 2340)] Task finished successfully.
# 2023-05-07 22:19:56.130 [44/baseline/201 (pid 2455)] Task is starting.
# 2023-05-07 22:19:56.322 [44/model/202 (pid 2458)] Task is starting.
# 2023-05-07 22:20:00.749 [44/model/202 (pid 2458)] 2023-05-07 22:20:00.748925: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-07 22:20:00.767 [44/model/202 (pid 2458)] vocab_sz: 100
# 2023-05-07 22:20:00.904 [44/model/202 (pid 2458)] epochs: 20
# 2023-05-07 22:20:00.904 [44/model/202 (pid 2458)] batch_size: 32
# 2023-05-07 22:20:00.904 [44/model/202 (pid 2458)] (22641,)
# 2023-05-07 22:20:00.904 [44/model/202 (pid 2458)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 22:20:01.908 [44/baseline/201 (pid 2455)] Task finished successfully.
# 2023-05-07 22:20:02.084 [44/model/202 (pid 2458)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 22:20:02.085 [44/model/202 (pid 2458)] Epoch 1/20
# 2023-05-07 22:20:02.085 [44/model/202 (pid 2458)] 2023-05-07 22:20:01.799030: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 566/566 [==============================] - 1s 2ms/step - loss: 0.5006 - accuracy: 0.7599 - val_loss: 0.4157 - val_accuracy: 0.81417326 - accuracy: 0.34
# 2023-05-07 22:20:02.982 [44/model/202 (pid 2458)] Epoch 2/20
# 566/566 [==============================] - 0s 747us/step - loss: 0.4221 - accuracy: 0.8140 - val_loss: 0.4127 - val_accuracy: 0.8150 - accuracy: 0.75
# 2023-05-07 22:20:03.406 [44/model/202 (pid 2458)] Epoch 3/20
# 566/566 [==============================] - 0s 756us/step - loss: 0.4153 - accuracy: 0.8087 - val_loss: 0.4117 - val_accuracy: 0.8192 - accuracy: 0.81
# 2023-05-07 22:20:03.835 [44/model/202 (pid 2458)] Epoch 4/20
# 566/566 [==============================] - 0s 767us/step - loss: 0.4049 - accuracy: 0.8179 - val_loss: 0.4117 - val_accuracy: 0.8178 - accuracy: 0.81
# 2023-05-07 22:20:04.270 [44/model/202 (pid 2458)] Epoch 5/20
# 566/566 [==============================] - 0s 759us/step - loss: 0.4116 - accuracy: 0.8141 - val_loss: 0.4143 - val_accuracy: 0.8163 - accuracy: 0.68
# 566/566 [==============================] - 1s 904us/step - loss: 0.2463 - accuracy: 0.9104 - val_loss: 0.3924 - val_accuracy: 0.8485 - accuracy: 0.75
# 2023-05-07 22:20:31.360 [44/model/202 (pid 2458)] Epoch 16/20
# 566/566 [==============================] - 1s 907us/step - loss: 0.2476 - accuracy: 0.9128 - val_loss: 0.3982 - val_accuracy: 0.8446 - accuracy: 0.90
# 2023-05-07 22:20:31.874 [44/model/202 (pid 2458)] Epoch 17/20
# 566/566 [==============================] - 1s 897us/step - loss: 0.2369 - accuracy: 0.9148 - val_loss: 0.4031 - val_accuracy: 0.8437 - accuracy: 0.93
# 2023-05-07 22:20:32.383 [44/model/202 (pid 2458)] Epoch 18/20
# 566/566 [==============================] - 1s 899us/step - loss: 0.2348 - accuracy: 0.9169 - val_loss: 0.4133 - val_accuracy: 0.8443 - accuracy: 0.96
# 2023-05-07 22:20:32.892 [44/model/202 (pid 2458)] Epoch 19/20
# 566/566 [==============================] - 1s 902us/step - loss: 0.2286 - accuracy: 0.9215 - val_loss: 0.4144 - val_accuracy: 0.8421 - accuracy: 1.00
# 2023-05-07 22:20:33.404 [44/model/202 (pid 2458)] Epoch 20/20
# 566/566 [==============================] - 1s 895us/step - loss: 0.2315 - accuracy: 0.9228 - val_loss: 0.4253 - val_accuracy: 0.8452 - accuracy: 0.93
# 2023-05-07 22:20:33.915 [44/model/202 (pid 2458)] (4529,)
# 2023-05-07 22:20:34.167 [44/model/202 (pid 2458)] Oh how i have searched for a mid-rise bottom that was not matronly, and finally i have found one! they cover just enough of the back without looking like my mothers bathing suit butt, and the ruched sides add just enough interest to not be boring in a solid color. and speaking of the color, the blue is beautiful. i am happy with these and hope they hold up for several years. i am 125 lbs and the small fit perfect.
# 2023-05-07 22:20:34.167 [44/model/202 (pid 2458)] (4529,)
# 2023-05-07 22:20:37.102 [44/model/202 (pid 2458)] 2023-05-07 22:20:01.816743: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# 2023-05-07 22:20:37.103 [44/model/202 (pid 2458)] Oh how i have searched for a mid-rise bottom that was not matronly, and finally i have found one! they cover just enough of the back without looking like my mothers bathing suit butt, and the ruched sides add just enough interest to not be boring in a solid color. and speaking of the color, the blue is beautiful. i am happy with these and hope they hold up for several years. i am 125 lbs and the small fit perfect.
# 2023-05-07 22:20:37.348 [44/model/202 (pid 2458)] Task finished successfully.
# 2023-05-07 22:20:37.767 [44/aggregate/203 (pid 2890)] Task is starting.
# 2023-05-07 22:20:40.456 [44/aggregate/203 (pid 2890)] Task finished successfully.
# 2023-05-07 22:20:40.759 [44/end/204 (pid 2954)] Task is starting.
# 2023-05-07 22:20:43.210 [44/end/204 (pid 2954)] Task finished successfully.
# 2023-05-07 22:20:43.340 Done! See the run in the UI at https://ui-pw-2141923211.outerbounds.dev/BaselineChallenge/44

# %% [markdown]
# ## Task 2: Anticipating Failure in Your Machine Learning Project
#
# In this task, you'll practice anticipating potential failure modes in a sentiment analysis classifier and develop strategies to mitigate them. Here's what you'll need to do:
# ### Step 1: Identify Potential Failure Modes
#
# The first step in anticipating failure in your machine learning project is to identify potential failure modes. Start by brainstorming ways in which your project could fail from an engineering point of view. For example, your model could overfit to the training data or suffer from data bias.
#
# Surveys are a common data source in the health industry. Because survey questions may address sensitive issues surrounding health outcomes and access to healthcare, missing data is quite commonplace. To mitigate bias in training data, the data scientist must differentiate between for instance, data missing completely at random (no difference between respondents with and without missing data), and data missing at random, where a defined subset of respondents is less likely to respond to the missing question.
#
# Another scenario, in the instance of claims data, could be a dataset containing hundreds of features, everything from age, employment status, income and zipcode; to HbA1C results (lab test for assessing glycemic control and Type 2 Diabetes management), medication history and blood pressure; with the aim of predicting the likelihood of a hypertension diagnosis.
#
# ### Step 2: Develop Strategies to Mitigate Failure Modes
#
# Once you've identified potential failure modes, the next step is to develop strategies to mitigate them. Think about what measures you could take to fix the issue if it were to occur. For example, if your model is overfitting to the training data, you could try regularization techniques such as L1 or L2 regularization to reduce the complexity of the model.
# Pilot testing is a key strategy to mitigate the scenario of MAR (missing at random) data. In the case of a dataset with hundreds of features, it would be important to assess features which are closely correlated with one another, and implement regularization strategies as needed.
#
# ### Step 3: Plan Ahead to Avoid Failure Modes
#
# Finally, it's important to plan ahead to avoid potential failure modes in the first place. Think about what you could have done initially to avoid these failure modes. For example, you could have collected a diverse set of training data to reduce data bias or experimented with different model architectures to find the best solution for your problem.
#
# The key to anticipating failure in your machine learning project is to be proactive rather than reactive. By identifying potential failure modes ahead of time and developing strategies to mitigate them, you'll be better equipped to build a successful machine learning project.

# %% [markdown]
# ## Task 3: Visualizing ML Results with MF Cards
# Now it is time to iterate. Extend the flow in your `baseline_challenge.py` file to include a step that aggregates all of the results from hyperparameter tuning jobs, and logs results and a data visualiation in a Metaflow card.

# %%
# %%writefile baseline_challenge_2.py
# TODO: In this cell, write your BaselineChallenge flow in the baseline_challenge.py file.

from metaflow import FlowSpec, step, Flow, current, Parameter, IncludeFile, card, current
from metaflow.cards import Table, Markdown, Artifact, Image
import numpy as np 
from dataclasses import dataclass

# labeling_function = ... 
# TODO: Define your labeling function here.
def labeling_function(row):
    """
    A function to derive labels from the user's review data.
    """
    # TODO: Add your logic for the labelling function here
    try:
        if int(row['rating']) >= 4:
            return 1
        else:
            return 0
    except:
        return np.nan

@dataclass
class ModelResult:
    "A custom struct for storing model evaluation results."
    name: None
    params: None
    pathspec: None
    acc: None
    rocauc: None

class BaselineChallenge_1(FlowSpec):

    split_size = Parameter('split-sz', default=0.2)
    data = IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv')
    kfold = Parameter('k', default=5)
    scoring = Parameter('scoring', default='accuracy')

    @step
    def start(self):

        import pandas as pd
        import io 
        from sklearn.model_selection import train_test_split
        
        # load dataset packaged with the flow.
        # this technique is convenient when working with small datasets that need to move to remove tasks.
        # df = ... 
        # TODO: load the data. 
        df = pd.read_csv(io.StringIO(self.data), index_col=0)
        # Look up a few lines to the IncludeFile('data', default='Womens Clothing E-Commerce Reviews.csv'). 
        # You can find documentation on IncludeFile here: https://docs.metaflow.org/scaling/data#data-in-local-files


        # filter down to reviews and labels 
        df.columns = ["_".join(name.lower().strip().split()) for name in df.columns]
        df = df[~df.review_text.isna()]
        df['review'] = df['review_text'].astype('str')
        _has_review_df = df[df['review_text'] != 'nan']
        reviews = _has_review_df['review_text']
        labels = _has_review_df.apply(labeling_function, axis=1)
        self.df = pd.DataFrame({'label': labels, **_has_review_df})

        # split the data 80/20, or by using the flow's split-sz CLI argument
        _df = pd.DataFrame({'review': reviews, 'label': labels})
        self.traindf, self.valdf = train_test_split(_df, test_size=self.split_size)
        print(f'num of rows in train set: {self.traindf.shape[0]}')
        print(f'num of rows in validation set: {self.valdf.shape[0]}')

        self.next(self.baseline, self.model)

    @step
    def baseline(self):
        "Compute the baseline model"

        #import relevant packages
        from sklearn.metrics import accuracy_score, roc_auc_score
        from sklearn.dummy import DummyClassifier

        self._name = "baseline"
        params = "Always predict 1"
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        maj_clf = DummyClassifier(strategy="most_frequent")
        maj_clf.fit(self.traindf["review"], self.traindf["label"])
    
        predictions = maj_clf.predict(self.valdf["review"]) # TODO: predict the majority class
        acc = accuracy_score(self.valdf["label"], predictions) # TODO: return the accuracy_score of these predictions
         
        rocauc = roc_auc_score(self.valdf["label"], predictions) # TODO: return the roc_auc_score of these predictions
        self.result = ModelResult("Baseline", params, pathspec, acc, rocauc)
        self.next(self.aggregate)

    @step
    def model(self):

        # TODO: import your model if it is defined in another file.
        from model_1 import NbowModel

        self._name = "model"
        # NOTE: If you followed the link above to find a custom model implementation, 
            # you will have noticed your model's vocab_sz hyperparameter.
            # Too big of vocab_sz causes an error. Can you explain why? 
        self.hyperparam_set = [{'vocab_sz': 100, "epochs": 20, "batch_size": 32}, {'vocab_sz': 300, "epochs": 20, "batch_size": 32}, {'vocab_sz': 500, "epochs": 20, "batch_size": 32}]   
        pathspec = f"{current.flow_name}/{current.run_id}/{current.step_name}/{current.task_id}"

        self.results = []
        for params in self.hyperparam_set:
            model = NbowModel(params["vocab_sz"], params["epochs"], params["batch_size"]) # TODO: instantiate your custom model here!
            model.fit(X=self.df['review'], y=self.df['label'])
            acc = model.eval_acc(self.valdf["review"].values, self.valdf["label"]) # TODO: evaluate your custom model in an equivalent way to accuracy_score.
            rocauc = model.eval_rocauc(self.valdf["review"].values, self.valdf["label"]) # TODO: evaluate your custom model in an equivalent way to roc_auc_score.
            self.results.append(ModelResult(f"NbowModel - vocab_sz: {params['vocab_sz']}", params, pathspec, acc, rocauc))

        self.next(self.aggregate)

    def add_one(self, rows, result, df):
        "A helper function to load results."
        rows.append([
            Markdown(result.name),
            Artifact(result.params),
            Artifact(result.pathspec),
            Artifact(result.acc),
            Artifact(result.rocauc)
        ])
        df['name'].append(result.name)
        df['accuracy'].append(result.acc)
        return rows, df

    @card(type="corise") # TODO: Set your card type to "corise". 
            # I wonder what other card types there are?
            # https://docs.metaflow.org/metaflow/visualizing-results
            # https://github.com/outerbounds/metaflow-card-altair/blob/main/altairflow.py
    @step
    def aggregate(self, inputs):

        import seaborn as sns
        import matplotlib.pyplot as plt
        from matplotlib import rcParams 
        rcParams.update({'figure.autolayout': True})

        rows = []
        violin_plot_df = {'name': [], 'accuracy': []}
        for task in inputs:
            if task._name == "model": 
                for result in task.results:
                    print(result)
                    rows, violin_plot_df = self.add_one(rows, result, violin_plot_df)
            elif task._name == "baseline":
                print(task.result)
                rows, violin_plot_df = self.add_one(rows, task.result, violin_plot_df)
            else:
                raise ValueError("Unknown task._name type. Cannot parse results.")
            
        current.card.append(Markdown("# All models from this flow run"))

        # TODO: Add a Table of the results to your card! 
        current.card.append(
            Table(
                rows, # TODO: What goes here to populate the Table in the card? 
                headers=["Model name", "Params", "Task pathspec", "Accuracy", "ROCAUC"]
            )
        )
        
        fig, ax = plt.subplots(1,1)
        plt.xticks(rotation=40)
        sns.violinplot(data=violin_plot_df, x="name", y="accuracy", ax=ax)
        
        # TODO: Append the matplotlib fig to the card
        # Docs: https://docs.metaflow.org/metaflow/visualizing-results/easy-custom-reports-with-card-components#showing-plots
        current.card.append(Image.from_matplotlib(fig))
        self.next(self.end)

    @step
    def end(self):
        pass

if __name__ == '__main__':
    BaselineChallenge_1()
# Out:
# Overwriting baseline_challenge_2.py

# %%
! python baseline_challenge_2.py run --data "../data/Womens Clothing E-Commerce Reviews.csv"
# Out:
# Metaflow 2.8.3.1+ob(v1) executing BaselineChallenge_1 for user:sandbox
# Validating your flow...
#     The graph looks good!
# Running pylint...
#     Pylint is happy!
# Including file ../data/Womens Clothing E-Commerce Reviews.csv of size 8MB
# 2023-05-07 22:56:53.040 Workflow starting (run-id 45), see it in the UI at https://ui-pw-2141923211.outerbounds.dev/BaselineChallenge_1/45
# 2023-05-07 22:56:53.221 [45/start/206 (pid 3654)] Task is starting.
# 2023-05-07 22:56:56.159 [45/start/206 (pid 3654)] num of rows in train set: 18112
# 2023-05-07 22:56:59.118 [45/start/206 (pid 3654)] num of rows in validation set: 4529
# 2023-05-07 22:56:59.344 [45/start/206 (pid 3654)] Task finished successfully.
# 2023-05-07 22:56:59.619 [45/baseline/207 (pid 3766)] Task is starting.
# 2023-05-07 22:56:59.779 [45/model/208 (pid 3769)] Task is starting.
# 2023-05-07 22:57:04.179 [45/model/208 (pid 3769)] 2023-05-07 22:57:04.179247: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2023-05-07 22:57:04.199 [45/model/208 (pid 3769)] vocab_sz: 100
# 2023-05-07 22:57:04.377 [45/model/208 (pid 3769)] epochs: 20
# 2023-05-07 22:57:04.378 [45/model/208 (pid 3769)] batch_size: 32
# 2023-05-07 22:57:04.378 [45/model/208 (pid 3769)] (22641,)
# 2023-05-07 22:57:04.378 [45/model/208 (pid 3769)] Absolutely wonderful - silky and sexy and comfortable
# 2023-05-07 22:57:05.336 [45/baseline/207 (pid 3766)] Task finished successfully.
# 2023-05-07 22:57:05.486 [45/model/208 (pid 3769)] To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-07 22:57:05.486 [45/model/208 (pid 3769)] Epoch 1/20
# 2023-05-07 22:57:05.486 [45/model/208 (pid 3769)] 2023-05-07 22:57:05.210407: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 566/566 [==============================] - 1s 2ms/step - loss: 0.5099 - accuracy: 0.7563 - val_loss: 0.4161 - val_accuracy: 0.81747054 - accuracy: 0.56
# 2023-05-07 22:57:06.412 [45/model/208 (pid 3769)] Epoch 2/20
# 566/566 [==============================] - 0s 750us/step - loss: 0.4212 - accuracy: 0.8076 - val_loss: 0.4105 - val_accuracy: 0.8145 - accuracy: 0.78
# 2023-05-07 22:57:06.837 [45/model/208 (pid 3769)] Epoch 3/20
# 566/566 [==============================] - 0s 737us/step - loss: 0.4096 - accuracy: 0.8179 - val_loss: 0.4122 - val_accuracy: 0.8181 - accuracy: 0.84
# 2023-05-07 22:57:07.255 [45/model/208 (pid 3769)] Epoch 4/20
# 566/566 [==============================] - 0s 749us/step - loss: 0.4211 - accuracy: 0.8094 - val_loss: 0.4093 - val_accuracy: 0.8181 - accuracy: 0.78
# 2023-05-07 22:57:07.680 [45/model/208 (pid 3769)] Epoch 5/20
# 2023-05-07 22:57:34.006 [45/model/208 (pid 3769)] Epoch 15/20
# 566/566 [==============================] - 1s 890us/step - loss: 0.2358 - accuracy: 0.9168 - val_loss: 0.4050 - val_accuracy: 0.8426 - accuracy: 0.96
# 2023-05-07 22:57:34.511 [45/model/208 (pid 3769)] Epoch 16/20
# 566/566 [==============================] - 1s 988us/step - loss: 0.2284 - accuracy: 0.9204 - val_loss: 0.4099 - val_accuracy: 0.8435 - accuracy: 0.90
# 2023-05-07 22:57:35.071 [45/model/208 (pid 3769)] Epoch 17/20
# 566/566 [==============================] - 1s 889us/step - loss: 0.2298 - accuracy: 0.9178 - val_loss: 0.4252 - val_accuracy: 0.8410 - accuracy: 0.90
# 2023-05-07 22:57:35.575 [45/model/208 (pid 3769)] Epoch 18/20
# 566/566 [==============================] - 1s 895us/step - loss: 0.2295 - accuracy: 0.9211 - val_loss: 0.4264 - val_accuracy: 0.8373 - accuracy: 0.93
# 2023-05-07 22:57:36.082 [45/model/208 (pid 3769)] Epoch 19/20
# 566/566 [==============================] - 1s 887us/step - loss: 0.2267 - accuracy: 0.9241 - val_loss: 0.4318 - val_accuracy: 0.8390 - accuracy: 1.00
# 2023-05-07 22:57:36.585 [45/model/208 (pid 3769)] Epoch 20/20
# 566/566 [==============================] - 1s 919us/step - loss: 0.2233 - accuracy: 0.9227 - val_loss: 0.4471 - val_accuracy: 0.8373 - accuracy: 0.87
# 2023-05-07 22:57:37.110 [45/model/208 (pid 3769)] (4529,)
# 2023-05-07 22:57:37.383 [45/model/208 (pid 3769)] O.k. i soo wanted to love this dress. if you are slim and small chested it is true to size and lovely. i am slim and tall 5'9 but am large chested. a 36d i usually wear an 8/10 so bought a 10. it was too tight around my chest and back. so i went up a size to a 12. it was better but not exactly comfortable. i could get away with it but for the price had to send it back. the idea of going up another size yet again was a thought but i worried it wouldn't solve my issue.
# 2023-05-07 22:57:37.383 [45/model/208 (pid 3769)] (4529,)
# 2023-05-07 22:57:40.359 [45/model/208 (pid 3769)] 2023-05-07 22:57:05.228763: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# 2023-05-07 22:57:40.359 [45/model/208 (pid 3769)] O.k. i soo wanted to love this dress. if you are slim and small chested it is true to size and lovely. i am slim and tall 5'9 but am large chested. a 36d i usually wear an 8/10 so bought a 10. it was too tight around my chest and back. so i went up a size to a 12. it was better but not exactly comfortable. i could get away with it but for the price had to send it back. the idea of going up another size yet again was a thought but i worried it wouldn't solve my issue.
# 2023-05-07 22:57:40.585 [45/model/208 (pid 3769)] Task finished successfully.
# 2023-05-07 22:57:40.923 [45/aggregate/209 (pid 4204)] Task is starting.
# 2023-05-07 22:57:44.057 [45/aggregate/209 (pid 4204)] ModelResult(name='Baseline', params='Always predict 1', pathspec='BaselineChallenge_1/45/baseline/207', acc=0.7716935305807021, rocauc=0.5)
# 2023-05-07 22:57:44.101 [45/aggregate/209 (pid 4204)] ModelResult(name='NbowModel - vocab_sz: 100', params={'vocab_sz': 100, 'epochs': 20, 'batch_size': 32}, pathspec='BaselineChallenge_1/45/model/208', acc=0.8423493044822257, rocauc=0.8723337843783464)
# 2023-05-07 22:57:44.102 [45/aggregate/209 (pid 4204)] ModelResult(name='NbowModel - vocab_sz: 300', params={'vocab_sz': 300, 'epochs': 20, 'batch_size': 32}, pathspec='BaselineChallenge_1/45/model/208', acc=0.8935747405608302, rocauc=0.9444799561683865)
# 2023-05-07 22:57:46.831 [45/aggregate/209 (pid 4204)] ModelResult(name='NbowModel - vocab_sz: 500', params={'vocab_sz': 500, 'epochs': 20, 'batch_size': 32}, pathspec='BaselineChallenge_1/45/model/208', acc=0.93066902185913, rocauc=0.968567973590346)
# 2023-05-07 22:57:47.132 [45/aggregate/209 (pid 4204)] Task finished successfully.
# 2023-05-07 22:57:47.496 [45/end/210 (pid 4310)] Task is starting.
# 2023-05-07 22:57:49.989 [45/end/210 (pid 4310)] Task finished successfully.
# 2023-05-07 22:57:50.126 Done! See the run in the UI at https://ui-pw-2141923211.outerbounds.dev/BaselineChallenge_1/45
